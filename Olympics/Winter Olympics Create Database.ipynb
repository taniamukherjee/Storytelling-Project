# %%
import pandas as pd
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy import create_engine, MetaData
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float

# %%
# Create an engine to a SQLite database file called `winter_olympics.sqlite`
engine = create_engine("sqlite:///winter_olympics.sqlite")

# %%
# Create a connection to the engine called `conn`
conn = engine.connect()

# %%
# Use `declarative_base` from SQLAlchemy to model the measurement table as an ORM class

Base = declarative_base()

class Medals(Base):
    __tablename__ = 'medals'

    id = Column(Integer, primary_key=True)
    year = Column(Integer)
    sport = Column(Text)
    event = Column(Text)
    country = Column(Text)
    gender = Column(Text)
    medal_rank = Column(Integer)
    medal = Column(Text)
    name = Column(Text)
    age = Column(Integer)
   
    def __repr__(self):
        return f"id={self.id}, name={self.name}"
# More on __repr__: https://stackoverflow.com/questions/1984162/purpose-of-pythons-repr

# %%
# Create the measurement table in the database
Base.metadata.create_all(engine)

# %%
# Load the cleaned measurement csv file into a pandas dataframe
medals_df = pd.read_csv('Winter_Olympic_Medals.csv').fillna(value=0)
medals_df = medals_df.reset_index()
medals_df.columns = ["id","year","sport","event","country","gender","medal_rank","medal","name","age"]
medals_df
# Out:
#         id  year                 sport                        event  \
# 0        0  1924               Bobsled              Men's Four/Five
# 1        1  1924               Bobsled              Men's Four/Five
# 2        2  1924               Bobsled              Men's Four/Five
# 3        3  1924  Cross-Country Skiing          Men's 18 Kilometers
# 4        4  1924  Cross-Country Skiing          Men's 18 Kilometers
# 5        5  1924  Cross-Country Skiing          Men's 18 Kilometers
# 6        6  1924  Cross-Country Skiing          Men's 50 Kilometers
# 7        7  1924  Cross-Country Skiing          Men's 50 Kilometers
# 8        8  1924  Cross-Country Skiing          Men's 50 Kilometers
# 9        9  1924               Curling                Men's Curling
# 10      10  1924               Curling                Men's Curling
# 11      11  1924               Curling                Men's Curling
# 12      12  1924        Figure Skating                Men's Singles
# 13      13  1924        Figure Skating                Men's Singles
# 14      14  1924        Figure Skating                Men's Singles
# 15      15  1924        Figure Skating                  Mixed Pairs
# 16      16  1924        Figure Skating                  Mixed Pairs
# 17      17  1924        Figure Skating                  Mixed Pairs
# 18      18  1924        Figure Skating              Women's Singles
# 19      19  1924        Figure Skating              Women's Singles
# 20      20  1924        Figure Skating              Women's Singles
# 21      21  1924            Ice Hockey             Men's Ice Hockey
# 22      22  1924            Ice Hockey             Men's Ice Hockey
# 23      23  1924            Ice Hockey             Men's Ice Hockey
# 24      24  1924              Biathlon    Men's Military Ski Patrol
# 25      25  1924              Biathlon    Men's Military Ski Patrol
# 26      26  1924              Biathlon    Men's Military Ski Patrol
# 27      27  1924       Nordic Combined             Men's Individual
# 28      28  1924       Nordic Combined             Men's Individual
# 29      29  1924       Nordic Combined             Men's Individual
# ...    ...   ...                   ...                          ...
# 2835  2835  2014         Alpine Skiing                 Men's Slalom
# 2836  2836  2014         Alpine Skiing                 Men's Slalom
# 2837  2837  2014         Alpine Skiing                 Men's Slalom
# 2838  2838  2014              Biathlon  Men 4 x 7.5-Kilometer Relay
# 2839  2839  2014              Biathlon  Men 4 x 7.5-Kilometer Relay
# 2840  2840  2014              Biathlon  Men 4 x 7.5-Kilometer Relay
# 2841  2841  2014  Cross-Country Skiing        Women's 30 Kilometers
# 2842  2842  2014  Cross-Country Skiing        Women's 30 Kilometers
# 2843  2843  2014  Cross-Country Skiing        Women's 30 Kilometers
# 2844  2844  2014            Ice Hockey             Men's Ice Hockey
# 2845  2845  2014          Snowboarding      Women's Parallel Slalom
# 2846  2846  2014          Snowboarding      Women's Parallel Slalom
# 2847  2847  2014          Snowboarding      Women's Parallel Slalom
# 2848  2848  2014          Snowboarding        Men's Parallel Slalom
# 2849  2849  2014          Snowboarding        Men's Parallel Slalom
# 2850  2850  2014          Snowboarding        Men's Parallel Slalom
# 2851  2851  2014          Speedskating         Women's Team Pursuit
# 2852  2852  2014          Speedskating         Women's Team Pursuit
# 2853  2853  2014          Speedskating         Women's Team Pursuit
# 2854  2854  2014          Speedskating           Men's Team Pursuit
# 2855  2855  2014          Speedskating           Men's Team Pursuit
# 2856  2856  2014          Speedskating           Men's Team Pursuit
# 2857  2857  2014               Bobsled                   Men's Four
# 2858  2858  2014               Bobsled                   Men's Four
# 2859  2859  2014               Bobsled                   Men's Four
# 2860  2860  2014  Cross-Country Skiing          Men's 50 Kilometers
# 2861  2861  2014  Cross-Country Skiing          Men's 50 Kilometers
# 2862  2862  2014  Cross-Country Skiing          Men's 50 Kilometers
# 2863  2863  2014            Ice Hockey             Men's Ice Hockey
# 2864  2864  2014            Ice Hockey             Men's Ice Hockey
#
#             country gender  medal_rank   medal                     name   age
# 0       Switzerland    Men           1    gold            Switzerland-1   0.0
# 1           Britain    Men           2  silver                Britain-1   0.0
# 2           Belgium    Men           3  bronze                Belgium-1   0.0
# 3            Norway    Men           1    gold            Thorleif Haug  29.0
# 4            Norway    Men           2  silver   Johan GrÃ¸ttumsbraaten  24.0
# 5           Finland    Men           3  bronze              Tapani Niku  28.0
# 6            Norway    Men           1    gold            Thorleif Haug  29.0
# 7            Norway    Men           2  silver       Thoralf StrÃ¸mstad  27.0
# 8            Norway    Men           3  bronze   Johan GrÃ¸ttumsbraaten  24.0
# 9           Britain    Men           1    gold                  Britain   0.0
# 10           Sweden    Men           2  silver                   Sweden   0.0
# 11           France    Men           3  bronze                   France   0.0
# 12           Sweden    Men           1    gold        Gillis GrafstrÃ¶m  30.0
# 13          Austria    Men           2  silver             Willy BÃ¶ckl  30.0
# 14      Switzerland    Men           3  bronze         Georges Gautschi  19.0
# 15          Austria  Mixed           1    gold                  Austria   0.0
# 16          Finland  Mixed           2  silver                  Finland   0.0
# 17           France  Mixed           3  bronze                 France-1   0.0
# 18          Austria  Women           1    gold       Herma Planck-Szabo  21.0
# 19    United States  Women           2  silver         Beatrix Loughran  23.0
# 20          Britain  Women           3  bronze            Ethel Muckelt  38.0
# 21           Canada    Men           1    gold                   Canada   0.0
# 22    United States    Men           2  silver            United States   0.0
# 23          Britain    Men           3  bronze                  Britain   0.0
# 24      Switzerland    Men           1    gold              Switzerland   0.0
# 25          Finland    Men           2  silver                  Finland   0.0
# 26           France    Men           3  bronze                   France   0.0
# 27           Norway    Men           1    gold            Thorleif Haug  29.0
# 28           Norway    Men           2  silver       Thoralf StrÃ¸mstad  27.0
# 29           Norway    Men           3  bronze   Johan GrÃ¸ttumsbraaten  24.0
# ...             ...    ...         ...     ...                      ...   ...
# 2835        Austria    Men           1    gold               Mario Matt  34.0
# 2836        Austria    Men           2  silver          Marcel Hirscher  24.0
# 2837         Norway    Men           3  bronze     Henrik Kristoffersen  19.0
# 2838         Russia    Men           1    gold                   Russia   0.0
# 2839        Germany    Men           2  silver                  Germany   0.0
# 2840        Austria    Men           3  bronze                  Austria   0.0
# 2841         Norway  Women           1    gold           Marit Bjoergen  33.0
# 2842         Norway  Women           2  silver           Therese Johaug  25.0
# 2843         Norway  Women           3  bronze  Kristin Stoermer Steira  32.0
# 2844        Finland    Men           3  bronze                  Finland   0.0
# 2845        Austria  Women           1    gold          Julia Dujmovits  26.0
# 2846        Germany  Women           2  silver            Anke Karstens  28.0
# 2847        Germany  Women           3  bronze             Amelie Kober  26.0
# 2848         Russia    Men           1    gold                 Vic Wild  27.0
# 2849       Slovenia    Men           2  silver                Zan Kosir  29.0
# 2850        Austria    Men           3  bronze            Benjamin Karl  28.0
# 2851    Netherlands  Women           1    gold              Netherlands   0.0
# 2852         Poland  Women           2  silver                   Poland   0.0
# 2853         Russia  Women           3  bronze                   Russia   0.0
# 2854    Netherlands    Men           1    gold              Netherlands   0.0
# 2855    South Korea    Men           2  silver              South Korea   0.0
# 2856         Poland    Men           3  bronze                   Poland   0.0
# 2857         Russia    Men           1    gold                   Russia   0.0
# 2858         Latvia    Men           2  silver                   Latvia   0.0
# 2859  United States    Men           3  bronze            United States   0.0
# 2860         Russia    Men           1    gold         Alexander Legkov  30.0
# 2861         Russia    Men           2  silver        Maxim Vylegzhanin  31.0
# 2862         Russia    Men           3  bronze          Ilia Chernousov  27.0
# 2863         Canada    Men           1    gold                   Canada   0.0
# 2864         Sweden    Men           2  silver                   Sweden   0.0
#
# [2865 rows x 10 columns]

# %%
# Create a list of data to write
medals_data = medals_df.to_dict(orient='records')
medals_data
# Out:
# [{'age': 0.0,
#   'country': 'Switzerland',
#   'event': "Men's Four/Five",
#   'gender': 'Men',
#   'id': 0,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Switzerland-1',
#   'sport': 'Bobsled',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'Britain',
#   'event': "Men's Four/Five",
#   'gender': 'Men',
#   'id': 1,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Britain-1',
#   'sport': 'Bobsled',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'Belgium',
#   'event': "Men's Four/Five",
#   'gender': 'Men',
#   'id': 2,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Belgium-1',
#   'sport': 'Bobsled',
#   'year': 1924},
#  {'age': 29.0,
#   'country': 'Norway',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 3,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Thorleif Haug',
#   'sport': 'Cross-Country Skiing',
#   'year': 1924},
#  {'age': 24.0,
#   'country': 'Norway',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 4,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Johan GrÃ¸ttumsbraaten',
#   'sport': 'Cross-Country Skiing',
#   'year': 1924},
#  {'age': 28.0,
#   'country': 'Finland',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 5,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Tapani Niku',
#   'sport': 'Cross-Country Skiing',
#   'year': 1924},
#  {'age': 29.0,
#   'country': 'Norway',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 6,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Thorleif Haug',
#   'sport': 'Cross-Country Skiing',
#   'year': 1924},
#  {'age': 27.0,
#   'country': 'Norway',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 7,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Thoralf StrÃ¸mstad',
#   'sport': 'Cross-Country Skiing',
#   'year': 1924},
#  {'age': 24.0,
#   'country': 'Norway',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 8,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Johan GrÃ¸ttumsbraaten',
#   'sport': 'Cross-Country Skiing',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'Britain',
#   'event': "Men's Curling",
#   'gender': 'Men',
#   'id': 9,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Britain',
#   'sport': 'Curling',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'Sweden',
#   'event': "Men's Curling",
#   'gender': 'Men',
#   'id': 10,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Sweden',
#   'sport': 'Curling',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'France',
#   'event': "Men's Curling",
#   'gender': 'Men',
#   'id': 11,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'France',
#   'sport': 'Curling',
#   'year': 1924},
#  {'age': 30.0,
#   'country': 'Sweden',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 12,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Gillis GrafstrÃ¶m',
#   'sport': 'Figure Skating',
#   'year': 1924},
#  {'age': 30.0,
#   'country': 'Austria',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 13,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Willy BÃ¶ckl',
#   'sport': 'Figure Skating',
#   'year': 1924},
#  {'age': 19.0,
#   'country': 'Switzerland',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 14,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Georges Gautschi',
#   'sport': 'Figure Skating',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'Austria',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 15,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Austria',
#   'sport': 'Figure Skating',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'Finland',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 16,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Finland',
#   'sport': 'Figure Skating',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'France',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 17,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'France-1',
#   'sport': 'Figure Skating',
#   'year': 1924},
#  {'age': 21.0,
#   'country': 'Austria',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 18,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Herma Planck-Szabo',
#   'sport': 'Figure Skating',
#   'year': 1924},
#  {'age': 23.0,
#   'country': 'United States',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 19,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Beatrix Loughran',
#   'sport': 'Figure Skating',
#   'year': 1924},
#  {'age': 38.0,
#   'country': 'Britain',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 20,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Ethel Muckelt',
#   'sport': 'Figure Skating',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'Canada',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 21,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Canada',
#   'sport': 'Ice Hockey',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 22,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'United States',
#   'sport': 'Ice Hockey',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'Britain',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 23,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Britain',
#   'sport': 'Ice Hockey',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'Switzerland',
#   'event': "Men's Military Ski Patrol",
#   'gender': 'Men',
#   'id': 24,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Switzerland',
#   'sport': 'Biathlon',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'Finland',
#   'event': "Men's Military Ski Patrol",
#   'gender': 'Men',
#   'id': 25,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Finland',
#   'sport': 'Biathlon',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'France',
#   'event': "Men's Military Ski Patrol",
#   'gender': 'Men',
#   'id': 26,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'France',
#   'sport': 'Biathlon',
#   'year': 1924},
#  {'age': 29.0,
#   'country': 'Norway',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 27,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Thorleif Haug',
#   'sport': 'Nordic Combined',
#   'year': 1924},
#  {'age': 27.0,
#   'country': 'Norway',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 28,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Thoralf StrÃ¸mstad',
#   'sport': 'Nordic Combined',
#   'year': 1924},
#  {'age': 24.0,
#   'country': 'Norway',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 29,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Johan GrÃ¸ttumsbraaten',
#   'sport': 'Nordic Combined',
#   'year': 1924},
#  {'age': 25.0,
#   'country': 'Norway',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 30,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Jacob Tullin Thams',
#   'sport': 'Ski Jumping',
#   'year': 1924},
#  {'age': 23.0,
#   'country': 'Norway',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 31,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Narve Bonna',
#   'sport': 'Ski Jumping',
#   'year': 1924},
#  {'age': 35.0,
#   'country': 'United States',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 32,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Anders Haugen',
#   'sport': 'Ski Jumping',
#   'year': 1924},
#  {'age': 23.0,
#   'country': 'United States',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 33,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Charley Jewtraw',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 26.0,
#   'country': 'Norway',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 34,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Oskar Olsen',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 26.0,
#   'country': 'Norway',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 35,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Roald Larsen',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 30.0,
#   'country': 'Finland',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 36,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Clas Thunberg',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 30.0,
#   'country': 'Finland',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 37,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Clas Thunberg',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 26.0,
#   'country': 'Norway',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 38,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Roald Larsen',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 26.0,
#   'country': 'Norway',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 39,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Sigurd Moen',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 30.0,
#   'country': 'Finland',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 40,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Clas Thunberg',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 34.0,
#   'country': 'Finland',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 41,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Julius Skutnabb',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 26.0,
#   'country': 'Norway',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 42,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Roald Larsen',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 34.0,
#   'country': 'Finland',
#   'event': "Men's 10,000 Meters",
#   'gender': 'Men',
#   'id': 43,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Julius Skutnabb',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 30.0,
#   'country': 'Finland',
#   'event': "Men's 10,000 Meters",
#   'gender': 'Men',
#   'id': 44,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Clas Thunberg',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 26.0,
#   'country': 'Norway',
#   'event': "Men's 10,000 Meters",
#   'gender': 'Men',
#   'id': 45,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Roald Larsen',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 30.0,
#   'country': 'Finland',
#   'event': "Men's Allround",
#   'gender': 'Men',
#   'id': 46,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Clas Thunberg',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 26.0,
#   'country': 'Norway',
#   'event': "Men's Allround",
#   'gender': 'Men',
#   'id': 47,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Roald Larsen',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 34.0,
#   'country': 'Finland',
#   'event': "Men's Allround",
#   'gender': 'Men',
#   'id': 48,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Julius Skutnabb',
#   'sport': 'Speedskating',
#   'year': 1924},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Four/Five",
#   'gender': 'Men',
#   'id': 49,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'United States-2',
#   'sport': 'Bobsled',
#   'year': 1928},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Four/Five",
#   'gender': 'Men',
#   'id': 50,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'United States-1',
#   'sport': 'Bobsled',
#   'year': 1928},
#  {'age': 0.0,
#   'country': 'Germany',
#   'event': "Men's Four/Five",
#   'gender': 'Men',
#   'id': 51,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Germany-2',
#   'sport': 'Bobsled',
#   'year': 1928},
#  {'age': 28.0,
#   'country': 'Norway',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 52,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Johan GrÃ¸ttumsbraaten',
#   'sport': 'Cross-Country Skiing',
#   'year': 1928},
#  {'age': 29.0,
#   'country': 'Norway',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 53,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Ole Hegge',
#   'sport': 'Cross-Country Skiing',
#   'year': 1928},
#  {'age': 26.0,
#   'country': 'Norway',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 54,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Reidar Ã˜degÃ¥rd',
#   'sport': 'Cross-Country Skiing',
#   'year': 1928},
#  {'age': 30.0,
#   'country': 'Sweden',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 55,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Per Erik Hedlund',
#   'sport': 'Cross-Country Skiing',
#   'year': 1928},
#  {'age': 24.0,
#   'country': 'Sweden',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 56,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Gustaf Jonsson',
#   'sport': 'Cross-Country Skiing',
#   'year': 1928},
#  {'age': 32.0,
#   'country': 'Sweden',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 57,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Volger Andersson',
#   'sport': 'Cross-Country Skiing',
#   'year': 1928},
#  {'age': 34.0,
#   'country': 'Sweden',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 58,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Gillis GrafstrÃ¶m',
#   'sport': 'Figure Skating',
#   'year': 1928},
#  {'age': 35.0,
#   'country': 'Austria',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 59,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Willy BÃ¶ckl',
#   'sport': 'Figure Skating',
#   'year': 1928},
#  {'age': 18.0,
#   'country': 'Belgium',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 60,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Robert Van Zeebroeck',
#   'sport': 'Figure Skating',
#   'year': 1928},
#  {'age': 0.0,
#   'country': 'France',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 61,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'France',
#   'sport': 'Figure Skating',
#   'year': 1928},
#  {'age': 0.0,
#   'country': 'Austria',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 62,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Austria-1',
#   'sport': 'Figure Skating',
#   'year': 1928},
#  {'age': 0.0,
#   'country': 'Austria',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 63,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Austria-2',
#   'sport': 'Figure Skating',
#   'year': 1928},
#  {'age': 15.0,
#   'country': 'Norway',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 64,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Sonja Henie',
#   'sport': 'Figure Skating',
#   'year': 1928},
#  {'age': 17.0,
#   'country': 'Austria',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 65,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Fritzi Burger',
#   'sport': 'Figure Skating',
#   'year': 1928},
#  {'age': 27.0,
#   'country': 'United States',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 66,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Beatrix Loughran',
#   'sport': 'Figure Skating',
#   'year': 1928},
#  {'age': 0.0,
#   'country': 'Canada',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 67,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Canada',
#   'sport': 'Ice Hockey',
#   'year': 1928},
#  {'age': 0.0,
#   'country': 'Sweden',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 68,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Sweden',
#   'sport': 'Ice Hockey',
#   'year': 1928},
#  {'age': 0.0,
#   'country': 'Switzerland',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 69,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Switzerland',
#   'sport': 'Ice Hockey',
#   'year': 1928},
#  {'age': 28.0,
#   'country': 'Norway',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 70,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Johan GrÃ¸ttumsbraaten',
#   'sport': 'Nordic Combined',
#   'year': 1928},
#  {'age': 22.0,
#   'country': 'Norway',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 71,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Hans Vinjarengen',
#   'sport': 'Nordic Combined',
#   'year': 1928},
#  {'age': 25.0,
#   'country': 'Norway',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 72,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'John Snersrud',
#   'sport': 'Nordic Combined',
#   'year': 1928},
#  {'age': 23.0,
#   'country': 'United States',
#   'event': "Men's Skeleton",
#   'gender': 'Men',
#   'id': 73,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Jennison Heaton',
#   'sport': 'Skeleton',
#   'year': 1928},
#  {'age': 19.0,
#   'country': 'United States',
#   'event': "Men's Skeleton",
#   'gender': 'Men',
#   'id': 74,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Jack Heaton',
#   'sport': 'Skeleton',
#   'year': 1928},
#  {'age': 26.0,
#   'country': 'Britain',
#   'event': "Men's Skeleton",
#   'gender': 'Men',
#   'id': 75,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'David, Earl of Northesk',
#   'sport': 'Skeleton',
#   'year': 1928},
#  {'age': 21.0,
#   'country': 'Norway',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 76,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Alf Andersen',
#   'sport': 'Ski Jumping',
#   'year': 1928},
#  {'age': 20.0,
#   'country': 'Norway',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 77,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Sigmund Ruud',
#   'sport': 'Ski Jumping',
#   'year': 1928},
#  {'age': 23.0,
#   'country': 'Czechoslovakia',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 78,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Rudolf Burkert',
#   'sport': 'Ski Jumping',
#   'year': 1928},
#  {'age': 22.0,
#   'country': 'Norway',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 79,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Bernt Evensen',
#   'sport': 'Speedskating',
#   'year': 1928},
#  {'age': 34.0,
#   'country': 'Finland',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 80,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Clas Thunberg',
#   'sport': 'Speedskating',
#   'year': 1928},
#  {'age': 21.0,
#   'country': 'United States',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 81,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': "John O'Neil Farrell",
#   'sport': 'Speedskating',
#   'year': 1928},
#  {'age': 24.0,
#   'country': 'Finland',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 82,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Jaakko Friman',
#   'sport': 'Speedskating',
#   'year': 1928},
#  {'age': 30.0,
#   'country': 'Norway',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 83,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Roald Larsen',
#   'sport': 'Speedskating',
#   'year': 1928},
#  {'age': 34.0,
#   'country': 'Finland',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 84,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Clas Thunberg',
#   'sport': 'Speedskating',
#   'year': 1928},
#  {'age': 22.0,
#   'country': 'Norway',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 85,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Bernt Evensen',
#   'sport': 'Speedskating',
#   'year': 1928},
#  {'age': 23.0,
#   'country': 'Norway',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 86,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Ivar Ballangrud',
#   'sport': 'Speedskating',
#   'year': 1928},
#  {'age': 23.0,
#   'country': 'Norway',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 87,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Ivar Ballangrud',
#   'sport': 'Speedskating',
#   'year': 1928},
#  {'age': 38.0,
#   'country': 'Finland',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 88,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Julius Skutnabb',
#   'sport': 'Speedskating',
#   'year': 1928},
#  {'age': 22.0,
#   'country': 'Norway',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 89,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Bernt Evensen',
#   'sport': 'Speedskating',
#   'year': 1928},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Two",
#   'gender': 'Men',
#   'id': 90,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'United States-1',
#   'sport': 'Bobsled',
#   'year': 1932},
#  {'age': 0.0,
#   'country': 'Switzerland',
#   'event': "Men's Two",
#   'gender': 'Men',
#   'id': 91,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Switzerland-2',
#   'sport': 'Bobsled',
#   'year': 1932},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Two",
#   'gender': 'Men',
#   'id': 92,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'United States-2',
#   'sport': 'Bobsled',
#   'year': 1932},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Four",
#   'gender': 'Men',
#   'id': 93,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'United States-1',
#   'sport': 'Bobsled',
#   'year': 1932},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Four",
#   'gender': 'Men',
#   'id': 94,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'United States-2',
#   'sport': 'Bobsled',
#   'year': 1932},
#  {'age': 0.0,
#   'country': 'Germany',
#   'event': "Men's Four",
#   'gender': 'Men',
#   'id': 95,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Germany-1',
#   'sport': 'Bobsled',
#   'year': 1932},
#  {'age': 30.0,
#   'country': 'Sweden',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 96,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Sven UtterstrÃ¶m',
#   'sport': 'Cross-Country Skiing',
#   'year': 1932},
#  {'age': 24.0,
#   'country': 'Sweden',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 97,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Axel WikstrÃ¶m',
#   'sport': 'Cross-Country Skiing',
#   'year': 1932},
#  {'age': 29.0,
#   'country': 'Finland',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 98,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Veli Saarinen',
#   'sport': 'Cross-Country Skiing',
#   'year': 1932},
#  {'age': 29.0,
#   'country': 'Finland',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 99,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Veli Saarinen',
#   'sport': 'Cross-Country Skiing',
#   'year': 1932},
#  {'age': 28.0,
#   'country': 'Finland',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 100,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'VÃ¤inÃ¶ Liikkanen',
#   'sport': 'Cross-Country Skiing',
#   'year': 1932},
#  {'age': 26.0,
#   'country': 'Norway',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 101,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Arne Rustadstuen',
#   'sport': 'Cross-Country Skiing',
#   'year': 1932},
#  {'age': 22.0,
#   'country': 'Austria',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 102,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Karl SchÃ¤fer',
#   'sport': 'Figure Skating',
#   'year': 1932},
#  {'age': 38.0,
#   'country': 'Sweden',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 103,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Gillis GrafstrÃ¶m',
#   'sport': 'Figure Skating',
#   'year': 1932},
#  {'age': 22.0,
#   'country': 'Canada',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 104,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Bud Wilson',
#   'sport': 'Figure Skating',
#   'year': 1932},
#  {'age': 0.0,
#   'country': 'France',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 105,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'France',
#   'sport': 'Figure Skating',
#   'year': 1932},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 106,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'United States-1',
#   'sport': 'Figure Skating',
#   'year': 1932},
#  {'age': 0.0,
#   'country': 'Hungary',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 107,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Hungary-1',
#   'sport': 'Figure Skating',
#   'year': 1932},
#  {'age': 19.0,
#   'country': 'Norway',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 108,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Sonja Henie',
#   'sport': 'Figure Skating',
#   'year': 1932},
#  {'age': 21.0,
#   'country': 'Austria',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 109,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Fritzi Burger',
#   'sport': 'Figure Skating',
#   'year': 1932},
#  {'age': 20.0,
#   'country': 'United States',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 110,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Maribel Vinson',
#   'sport': 'Figure Skating',
#   'year': 1932},
#  {'age': 0.0,
#   'country': 'Canada',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 111,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Canada',
#   'sport': 'Ice Hockey',
#   'year': 1932},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 112,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'United States',
#   'sport': 'Ice Hockey',
#   'year': 1932},
#  {'age': 0.0,
#   'country': 'Germany',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 113,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Germany',
#   'sport': 'Ice Hockey',
#   'year': 1932},
#  {'age': 32.0,
#   'country': 'Norway',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 114,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Johan GrÃ¸ttumsbraaten',
#   'sport': 'Nordic Combined',
#   'year': 1932},
#  {'age': 28.0,
#   'country': 'Norway',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 115,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Ole Stenen',
#   'sport': 'Nordic Combined',
#   'year': 1932},
#  {'age': 26.0,
#   'country': 'Norway',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 116,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Hans Vinjarengen',
#   'sport': 'Nordic Combined',
#   'year': 1932},
#  {'age': 20.0,
#   'country': 'Norway',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 117,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Birger Ruud',
#   'sport': 'Ski Jumping',
#   'year': 1932},
#  {'age': 20.0,
#   'country': 'Norway',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 118,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Hans Beck',
#   'sport': 'Ski Jumping',
#   'year': 1932},
#  {'age': 19.0,
#   'country': 'Norway',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 119,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'KÃ¥re Walberg',
#   'sport': 'Ski Jumping',
#   'year': 1932},
#  {'age': 21.0,
#   'country': 'United States',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 120,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Jack Shea',
#   'sport': 'Speedskating',
#   'year': 1932},
#  {'age': 26.0,
#   'country': 'Norway',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 121,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Bernt Evensen',
#   'sport': 'Speedskating',
#   'year': 1932},
#  {'age': 21.0,
#   'country': 'Canada',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 122,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Alex Hurd',
#   'sport': 'Speedskating',
#   'year': 1932},
#  {'age': 21.0,
#   'country': 'United States',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 123,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Jack Shea',
#   'sport': 'Speedskating',
#   'year': 1932},
#  {'age': 21.0,
#   'country': 'Canada',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 124,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Alex Hurd',
#   'sport': 'Speedskating',
#   'year': 1932},
#  {'age': 24.0,
#   'country': 'Canada',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 125,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Willy Logan',
#   'sport': 'Speedskating',
#   'year': 1932},
#  {'age': 25.0,
#   'country': 'United States',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 126,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Irving Jaffee',
#   'sport': 'Speedskating',
#   'year': 1932},
#  {'age': 27.0,
#   'country': 'United States',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 127,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Eddie Murphy',
#   'sport': 'Speedskating',
#   'year': 1932},
#  {'age': 24.0,
#   'country': 'Canada',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 128,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Willy Logan',
#   'sport': 'Speedskating',
#   'year': 1932},
#  {'age': 25.0,
#   'country': 'United States',
#   'event': "Men's 10,000 Meters",
#   'gender': 'Men',
#   'id': 129,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Irving Jaffee',
#   'sport': 'Speedskating',
#   'year': 1932},
#  {'age': 27.0,
#   'country': 'Norway',
#   'event': "Men's 10,000 Meters",
#   'gender': 'Men',
#   'id': 130,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Ivar Ballangrud',
#   'sport': 'Speedskating',
#   'year': 1932},
#  {'age': 26.0,
#   'country': 'Canada',
#   'event': "Men's 10,000 Meters",
#   'gender': 'Men',
#   'id': 131,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Frank Stack',
#   'sport': 'Speedskating',
#   'year': 1932},
#  {'age': 27.0,
#   'country': 'Germany',
#   'event': "Men's Combined",
#   'gender': 'Men',
#   'id': 132,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Franz PfnÃ¼r',
#   'sport': 'Alpine Skiing',
#   'year': 1936},
#  {'age': 25.0,
#   'country': 'Germany',
#   'event': "Men's Combined",
#   'gender': 'Men',
#   'id': 133,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Gustav Lantschner',
#   'sport': 'Alpine Skiing',
#   'year': 1936},
#  {'age': 23.0,
#   'country': 'France',
#   'event': "Men's Combined",
#   'gender': 'Men',
#   'id': 134,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Ã‰mile Allais',
#   'sport': 'Alpine Skiing',
#   'year': 1936},
#  {'age': 21.0,
#   'country': 'Germany',
#   'event': "Women's Combined",
#   'gender': 'Women',
#   'id': 135,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Christl Cranz',
#   'sport': 'Alpine Skiing',
#   'year': 1936},
#  {'age': 18.0,
#   'country': 'Germany',
#   'event': "Women's Combined",
#   'gender': 'Women',
#   'id': 136,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'KÃ¤the Grasegger',
#   'sport': 'Alpine Skiing',
#   'year': 1936},
#  {'age': 16.0,
#   'country': 'Norway',
#   'event': "Women's Combined",
#   'gender': 'Women',
#   'id': 137,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Laila Schou Nilsen',
#   'sport': 'Alpine Skiing',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Two",
#   'gender': 'Men',
#   'id': 138,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'United States-1',
#   'sport': 'Bobsled',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'Switzerland',
#   'event': "Men's Two",
#   'gender': 'Men',
#   'id': 139,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Switzerland-2',
#   'sport': 'Bobsled',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Two",
#   'gender': 'Men',
#   'id': 140,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'United States-2',
#   'sport': 'Bobsled',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'Switzerland',
#   'event': "Men's Four",
#   'gender': 'Men',
#   'id': 141,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Switzerland-2',
#   'sport': 'Bobsled',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'Switzerland',
#   'event': "Men's Four",
#   'gender': 'Men',
#   'id': 142,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Switzerland-1',
#   'sport': 'Bobsled',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'Britain',
#   'event': "Men's Four",
#   'gender': 'Men',
#   'id': 143,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Britain',
#   'sport': 'Bobsled',
#   'year': 1936},
#  {'age': 23.0,
#   'country': 'Sweden',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 144,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Erik Larsson',
#   'sport': 'Cross-Country Skiing',
#   'year': 1936},
#  {'age': 28.0,
#   'country': 'Norway',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 145,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'OddbjÃ¸rn Hagen',
#   'sport': 'Cross-Country Skiing',
#   'year': 1936},
#  {'age': 26.0,
#   'country': 'Finland',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 146,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Pekka Niemi',
#   'sport': 'Cross-Country Skiing',
#   'year': 1936},
#  {'age': 26.0,
#   'country': 'Sweden',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 147,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Elis Wiklund',
#   'sport': 'Cross-Country Skiing',
#   'year': 1936},
#  {'age': 28.0,
#   'country': 'Sweden',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 148,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Axel WikstrÃ¶m',
#   'sport': 'Cross-Country Skiing',
#   'year': 1936},
#  {'age': 28.0,
#   'country': 'Sweden',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 149,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Nils Englund',
#   'sport': 'Cross-Country Skiing',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'Finland',
#   'event': "Men's 4 Ã— 10-Kilometer Relay",
#   'gender': 'Men',
#   'id': 150,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Finland',
#   'sport': 'Cross-Country Skiing',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'Norway',
#   'event': "Men's 4 Ã— 10-Kilometer Relay",
#   'gender': 'Men',
#   'id': 151,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Norway',
#   'sport': 'Cross-Country Skiing',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'Sweden',
#   'event': "Men's 4 Ã— 10-Kilometer Relay",
#   'gender': 'Men',
#   'id': 152,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Sweden',
#   'sport': 'Cross-Country Skiing',
#   'year': 1936},
#  {'age': 26.0,
#   'country': 'Austria',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 153,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Karl SchÃ¤fer',
#   'sport': 'Figure Skating',
#   'year': 1936},
#  {'age': 30.0,
#   'country': 'Germany',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 154,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Ernst Baier',
#   'sport': 'Figure Skating',
#   'year': 1936},
#  {'age': 21.0,
#   'country': 'Austria',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 155,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Felix Kaspar',
#   'sport': 'Figure Skating',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'Germany',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 156,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Germany-1',
#   'sport': 'Figure Skating',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'Austria',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 157,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Austria-1',
#   'sport': 'Figure Skating',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'Hungary',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 158,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Hungary-1',
#   'sport': 'Figure Skating',
#   'year': 1936},
#  {'age': 23.0,
#   'country': 'Norway',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 159,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Sonja Henie',
#   'sport': 'Figure Skating',
#   'year': 1936},
#  {'age': 15.0,
#   'country': 'Britain',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 160,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Cecilia Colledge',
#   'sport': 'Figure Skating',
#   'year': 1936},
#  {'age': 24.0,
#   'country': 'Sweden',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 161,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Vivi-Anne HultÃ©n',
#   'sport': 'Figure Skating',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'Britain',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 162,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Britain',
#   'sport': 'Ice Hockey',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'Canada',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 163,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Canada',
#   'sport': 'Ice Hockey',
#   'year': 1936},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 164,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'United States',
#   'sport': 'Ice Hockey',
#   'year': 1936},
#  {'age': 28.0,
#   'country': 'Norway',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 165,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'OddbjÃ¸rn Hagen',
#   'sport': 'Nordic Combined',
#   'year': 1936},
#  {'age': 27.0,
#   'country': 'Norway',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 166,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Olaf Hoffsbakken',
#   'sport': 'Nordic Combined',
#   'year': 1936},
#  {'age': 27.0,
#   'country': 'Norway',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 167,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Sverre Brodahl',
#   'sport': 'Nordic Combined',
#   'year': 1936},
#  {'age': 24.0,
#   'country': 'Norway',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 168,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Birger Ruud',
#   'sport': 'Ski Jumping',
#   'year': 1936},
#  {'age': 28.0,
#   'country': 'Sweden',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 169,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Sven Eriksson',
#   'sport': 'Ski Jumping',
#   'year': 1936},
#  {'age': 24.0,
#   'country': 'Norway',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 170,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Reidar Andersen',
#   'sport': 'Ski Jumping',
#   'year': 1936},
#  {'age': 31.0,
#   'country': 'Norway',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 171,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Ivar Ballangrud',
#   'sport': 'Speedskating',
#   'year': 1936},
#  {'age': 20.0,
#   'country': 'Norway',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 172,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Georg Krog',
#   'sport': 'Speedskating',
#   'year': 1936},
#  {'age': 19.0,
#   'country': 'United States',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 173,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Leo Freisinger',
#   'sport': 'Speedskating',
#   'year': 1936},
#  {'age': 24.0,
#   'country': 'Norway',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 174,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Charles Mathiesen',
#   'sport': 'Speedskating',
#   'year': 1936},
#  {'age': 31.0,
#   'country': 'Norway',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 175,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Ivar Ballangrud',
#   'sport': 'Speedskating',
#   'year': 1936},
#  {'age': 24.0,
#   'country': 'Finland',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 176,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Birger Wasenius',
#   'sport': 'Speedskating',
#   'year': 1936},
#  {'age': 31.0,
#   'country': 'Norway',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 177,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Ivar Ballangrud',
#   'sport': 'Speedskating',
#   'year': 1936},
#  {'age': 24.0,
#   'country': 'Finland',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 178,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Birger Wasenius',
#   'sport': 'Speedskating',
#   'year': 1936},
#  {'age': 19.0,
#   'country': 'Finland',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 179,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Antero Ojala',
#   'sport': 'Speedskating',
#   'year': 1936},
#  {'age': 31.0,
#   'country': 'Norway',
#   'event': "Men's 10,000 Meters",
#   'gender': 'Men',
#   'id': 180,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Ivar Ballangrud',
#   'sport': 'Speedskating',
#   'year': 1936},
#  {'age': 24.0,
#   'country': 'Finland',
#   'event': "Men's 10,000 Meters",
#   'gender': 'Men',
#   'id': 181,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Birger Wasenius',
#   'sport': 'Speedskating',
#   'year': 1936},
#  {'age': 21.0,
#   'country': 'Austria',
#   'event': "Men's 10,000 Meters",
#   'gender': 'Men',
#   'id': 182,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Max Stiepl',
#   'sport': 'Speedskating',
#   'year': 1936},
#  {'age': 22.0,
#   'country': 'France',
#   'event': "Men's Downhill",
#   'gender': 'Men',
#   'id': 183,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Henri Oreiller',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 26.0,
#   'country': 'Austria',
#   'event': "Men's Downhill",
#   'gender': 'Men',
#   'id': 184,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Franz Gabl',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 27.0,
#   'country': 'Switzerland',
#   'event': "Men's Downhill",
#   'gender': 'Men',
#   'id': 185,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Karl Molitor',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 23.0,
#   'country': 'Switzerland',
#   'event': "Men's Downhill",
#   'gender': 'Men',
#   'id': 186,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Ralph Olinger',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 27.0,
#   'country': 'Switzerland',
#   'event': "Men's Slalom",
#   'gender': 'Men',
#   'id': 187,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Edy Reinalter',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 26.0,
#   'country': 'France',
#   'event': "Men's Slalom",
#   'gender': 'Men',
#   'id': 188,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'James Couttet',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 22.0,
#   'country': 'France',
#   'event': "Men's Slalom",
#   'gender': 'Men',
#   'id': 189,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Henri Oreiller',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 22.0,
#   'country': 'France',
#   'event': "Men's Combined",
#   'gender': 'Men',
#   'id': 190,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Henri Oreiller',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 27.0,
#   'country': 'Switzerland',
#   'event': "Men's Combined",
#   'gender': 'Men',
#   'id': 191,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Karl Molitor',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 26.0,
#   'country': 'France',
#   'event': "Men's Combined",
#   'gender': 'Men',
#   'id': 192,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'James Couttet',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 24.0,
#   'country': 'Switzerland',
#   'event': "Women's Downhill",
#   'gender': 'Women',
#   'id': 193,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Hedy Schlunegger',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 20.0,
#   'country': 'Austria',
#   'event': "Women's Downhill",
#   'gender': 'Women',
#   'id': 194,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Trude Jochum-Beiser',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 22.0,
#   'country': 'Austria',
#   'event': "Women's Downhill",
#   'gender': 'Women',
#   'id': 195,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Resi Hammerer',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 28.0,
#   'country': 'United States',
#   'event': "Women's Slalom",
#   'gender': 'Women',
#   'id': 196,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Gretchen Fraser',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 27.0,
#   'country': 'Switzerland',
#   'event': "Women's Slalom",
#   'gender': 'Women',
#   'id': 197,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Antoinette Meyer',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 23.0,
#   'country': 'Austria',
#   'event': "Women's Slalom",
#   'gender': 'Women',
#   'id': 198,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Erika Mahringer',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 20.0,
#   'country': 'Austria',
#   'event': "Women's Combined",
#   'gender': 'Women',
#   'id': 199,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Trude Jochum-Beiser',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 28.0,
#   'country': 'United States',
#   'event': "Women's Combined",
#   'gender': 'Women',
#   'id': 200,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Gretchen Fraser',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 23.0,
#   'country': 'Austria',
#   'event': "Women's Combined",
#   'gender': 'Women',
#   'id': 201,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Erika Mahringer',
#   'sport': 'Alpine Skiing',
#   'year': 1948},
#  {'age': 0.0,
#   'country': 'Switzerland',
#   'event': "Men's Two",
#   'gender': 'Men',
#   'id': 202,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Switzerland-2',
#   'sport': 'Bobsled',
#   'year': 1948},
#  {'age': 0.0,
#   'country': 'Switzerland',
#   'event': "Men's Two",
#   'gender': 'Men',
#   'id': 203,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Switzerland-1',
#   'sport': 'Bobsled',
#   'year': 1948},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Two",
#   'gender': 'Men',
#   'id': 204,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'United States-2',
#   'sport': 'Bobsled',
#   'year': 1948},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Four",
#   'gender': 'Men',
#   'id': 205,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'United States-2',
#   'sport': 'Bobsled',
#   'year': 1948},
#  {'age': 0.0,
#   'country': 'Belgium',
#   'event': "Men's Four",
#   'gender': 'Men',
#   'id': 206,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Belgium',
#   'sport': 'Bobsled',
#   'year': 1948},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Four",
#   'gender': 'Men',
#   'id': 207,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'United States-1',
#   'sport': 'Bobsled',
#   'year': 1948},
#  {'age': 29.0,
#   'country': 'Sweden',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 208,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Martin LundstrÃ¶m',
#   'sport': 'Cross-Country Skiing',
#   'year': 1948},
#  {'age': 29.0,
#   'country': 'Sweden',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 209,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Nils Ã–stensson',
#   'sport': 'Cross-Country Skiing',
#   'year': 1948},
#  {'age': 27.0,
#   'country': 'Sweden',
#   'event': "Men's 18 Kilometers",
#   'gender': 'Men',
#   'id': 210,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Gunnar Eriksson',
#   'sport': 'Cross-Country Skiing',
#   'year': 1948},
#  {'age': 30.0,
#   'country': 'Sweden',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 211,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Nils Karlsson',
#   'sport': 'Cross-Country Skiing',
#   'year': 1948},
#  {'age': 26.0,
#   'country': 'Sweden',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 212,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Harald Ericson',
#   'sport': 'Cross-Country Skiing',
#   'year': 1948},
#  {'age': 26.0,
#   'country': 'Finland',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 213,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Benjam Vanninen',
#   'sport': 'Cross-Country Skiing',
#   'year': 1948},
#  {'age': 0.0,
#   'country': 'Sweden',
#   'event': "Men's 4 Ã— 10-Kilometer Relay",
#   'gender': 'Men',
#   'id': 214,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Sweden',
#   'sport': 'Cross-Country Skiing',
#   'year': 1948},
#  {'age': 0.0,
#   'country': 'Finland',
#   'event': "Men's 4 Ã— 10-Kilometer Relay",
#   'gender': 'Men',
#   'id': 215,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Finland',
#   'sport': 'Cross-Country Skiing',
#   'year': 1948},
#  {'age': 0.0,
#   'country': 'Norway',
#   'event': "Men's 4 Ã— 10-Kilometer Relay",
#   'gender': 'Men',
#   'id': 216,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Norway',
#   'sport': 'Cross-Country Skiing',
#   'year': 1948},
#  {'age': 18.0,
#   'country': 'United States',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 217,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Dick Button',
#   'sport': 'Figure Skating',
#   'year': 1948},
#  {'age': 27.0,
#   'country': 'Switzerland',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 218,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Hans Gerschwiler',
#   'sport': 'Figure Skating',
#   'year': 1948},
#  {'age': 25.0,
#   'country': 'Austria',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 219,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Edi Rada',
#   'sport': 'Figure Skating',
#   'year': 1948},
#  {'age': 0.0,
#   'country': 'Belgium',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 220,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Belgium',
#   'sport': 'Figure Skating',
#   'year': 1948},
#  {'age': 0.0,
#   'country': 'Hungary',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 221,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Hungary-1',
#   'sport': 'Figure Skating',
#   'year': 1948},
#  {'age': 0.0,
#   'country': 'Canada',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 222,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Canada',
#   'sport': 'Figure Skating',
#   'year': 1948},
#  {'age': 19.0,
#   'country': 'Canada',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 223,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Barbara Ann Scott',
#   'sport': 'Figure Skating',
#   'year': 1948},
#  {'age': 20.0,
#   'country': 'Austria',
# ...
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'East Germany-2',
#   'sport': 'Bobsled',
#   'year': 1980},
#  {'age': 23.0,
#   'country': 'Sweden',
#   'event': "Men's 15 Kilometers",
#   'gender': 'Men',
#   'id': 928,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Thomas Wassberg',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 30.0,
#   'country': 'Finland',
#   'event': "Men's 15 Kilometers",
#   'gender': 'Men',
#   'id': 929,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Juha Mieto',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 23.0,
#   'country': 'Norway',
#   'event': "Men's 15 Kilometers",
#   'gender': 'Men',
#   'id': 930,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Ove Aunli',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 24.0,
#   'country': 'Soviet Union',
#   'event': "Men's 30 Kilometers",
#   'gender': 'Men',
#   'id': 931,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Nikolay Zimyatov',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 28.0,
#   'country': 'Soviet Union',
#   'event': "Men's 30 Kilometers",
#   'gender': 'Men',
#   'id': 932,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Vasily Rochev',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 22.0,
#   'country': 'Bulgaria',
#   'event': "Men's 30 Kilometers",
#   'gender': 'Men',
#   'id': 933,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Ivan Lebanov',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 24.0,
#   'country': 'Soviet Union',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 934,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Nikolay Zimyatov',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 30.0,
#   'country': 'Finland',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 935,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Juha Mieto',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 24.0,
#   'country': 'Soviet Union',
#   'event': "Men's 50 Kilometers",
#   'gender': 'Men',
#   'id': 936,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Aleksandr Zavyalov',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Soviet Union',
#   'event': "Men's 4 Ã— 10-Kilometer Relay",
#   'gender': 'Men',
#   'id': 937,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Soviet Union',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Norway',
#   'event': "Men's 4 Ã— 10-Kilometer Relay",
#   'gender': 'Men',
#   'id': 938,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Norway',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Finland',
#   'event': "Men's 4 Ã— 10-Kilometer Relay",
#   'gender': 'Men',
#   'id': 939,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Finland',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 27.0,
#   'country': 'Soviet Union',
#   'event': "Women's 5 Kilometers",
#   'gender': 'Women',
#   'id': 940,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Raisa Smetanina',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 27.0,
#   'country': 'Finland',
#   'event': "Women's 5 Kilometers",
#   'gender': 'Women',
#   'id': 941,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Hilkka Riihivuori-Kuntola',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 23.0,
#   'country': 'Czechoslovakia',
#   'event': "Women's 5 Kilometers",
#   'gender': 'Women',
#   'id': 942,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'KvÄ›ta JeriovÃ¡',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 24.0,
#   'country': 'East Germany',
#   'event': "Women's 10 Kilometers",
#   'gender': 'Women',
#   'id': 943,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Barbara Petzold',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 27.0,
#   'country': 'Finland',
#   'event': "Women's 10 Kilometers",
#   'gender': 'Women',
#   'id': 944,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Hilkka Riihivuori-Kuntola',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 32.0,
#   'country': 'Finland',
#   'event': "Women's 10 Kilometers",
#   'gender': 'Women',
#   'id': 945,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Helena Kivioja-Takalo',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'East Germany',
#   'event': "Women's 4 Ã— 5-Kilometer Relay",
#   'gender': 'Women',
#   'id': 946,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'East Germany',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Soviet Union',
#   'event': "Women's 4 Ã— 5-Kilometer Relay",
#   'gender': 'Women',
#   'id': 947,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Soviet Union',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Norway',
#   'event': "Women's 4 Ã— 5-Kilometer Relay",
#   'gender': 'Women',
#   'id': 948,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Norway',
#   'sport': 'Cross-Country Skiing',
#   'year': 1980},
#  {'age': 22.0,
#   'country': 'Britain',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 949,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Robin Cousins',
#   'sport': 'Figure Skating',
#   'year': 1980},
#  {'age': 24.0,
#   'country': 'East Germany',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 950,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Jan Hoffmann',
#   'sport': 'Figure Skating',
#   'year': 1980},
#  {'age': 26.0,
#   'country': 'United States',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 951,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Charlie Tickner',
#   'sport': 'Figure Skating',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Soviet Union',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 952,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Soviet Union-1',
#   'sport': 'Figure Skating',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Soviet Union',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 953,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Soviet Union-2',
#   'sport': 'Figure Skating',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'East Germany',
#   'event': 'Mixed Pairs',
#   'gender': 'Mixed',
#   'id': 954,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'East Germany-1',
#   'sport': 'Figure Skating',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Soviet Union',
#   'event': 'Mixed Ice Dancing',
#   'gender': 'Mixed',
#   'id': 955,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Soviet Union-1',
#   'sport': 'Figure Skating',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Hungary',
#   'event': 'Mixed Ice Dancing',
#   'gender': 'Mixed',
#   'id': 956,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Hungary',
#   'sport': 'Figure Skating',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Soviet Union',
#   'event': 'Mixed Ice Dancing',
#   'gender': 'Mixed',
#   'id': 957,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Soviet Union-2',
#   'sport': 'Figure Skating',
#   'year': 1980},
#  {'age': 19.0,
#   'country': 'East Germany',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 958,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Anett PÃ¶tzsch',
#   'sport': 'Figure Skating',
#   'year': 1980},
#  {'age': 19.0,
#   'country': 'United States',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 959,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Linda Fratianne',
#   'sport': 'Figure Skating',
#   'year': 1980},
#  {'age': 21.0,
#   'country': 'West Germany',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 960,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Dagmar Lurz',
#   'sport': 'Figure Skating',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'United States',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 961,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'United States',
#   'sport': 'Ice Hockey',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Soviet Union',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 962,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Soviet Union',
#   'sport': 'Ice Hockey',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Sweden',
#   'event': "Men's Ice Hockey",
#   'gender': 'Men',
#   'id': 963,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Sweden',
#   'sport': 'Ice Hockey',
#   'year': 1980},
#  {'age': 22.0,
#   'country': 'East Germany',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 964,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Bernhard Glass',
#   'sport': 'Luge',
#   'year': 1980},
#  {'age': 27.0,
#   'country': 'Italy',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 965,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Paul Hildgartner',
#   'sport': 'Luge',
#   'year': 1980},
#  {'age': 25.0,
#   'country': 'West Germany',
#   'event': "Men's Singles",
#   'gender': 'Men',
#   'id': 966,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Anton Winkler',
#   'sport': 'Luge',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'East Germany',
#   'event': "Men's Doubles",
#   'gender': 'Men',
#   'id': 967,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'East Germany-1',
#   'sport': 'Luge',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Italy',
#   'event': "Men's Doubles",
#   'gender': 'Men',
#   'id': 968,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Italy-1',
#   'sport': 'Luge',
#   'year': 1980},
#  {'age': 0.0,
#   'country': 'Austria',
#   'event': "Men's Doubles",
#   'gender': 'Men',
#   'id': 969,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Austria-1',
#   'sport': 'Luge',
#   'year': 1980},
#  {'age': 24.0,
#   'country': 'Soviet Union',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 970,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Vera ZozuÄ¼a',
#   'sport': 'Luge',
#   'year': 1980},
#  {'age': 21.0,
#   'country': 'East Germany',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 971,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Melitta Sollmann',
#   'sport': 'Luge',
#   'year': 1980},
#  {'age': 19.0,
#   'country': 'Soviet Union',
#   'event': "Women's Singles",
#   'gender': 'Women',
#   'id': 972,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'IngrÄ«da Amantova',
#   'sport': 'Luge',
#   'year': 1980},
#  {'age': 27.0,
#   'country': 'East Germany',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 973,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Ulrich Wehling',
#   'sport': 'Nordic Combined',
#   'year': 1980},
#  {'age': 23.0,
#   'country': 'Finland',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 974,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Jouko Karjalainen',
#   'sport': 'Nordic Combined',
#   'year': 1980},
#  {'age': 24.0,
#   'country': 'East Germany',
#   'event': "Men's Individual",
#   'gender': 'Men',
#   'id': 975,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Konrad Winkler',
#   'sport': 'Nordic Combined',
#   'year': 1980},
#  {'age': 21.0,
#   'country': 'Austria',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 976,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Toni Innauer',
#   'sport': 'Ski Jumping',
#   'year': 1980},
#  {'age': 18.0,
#   'country': 'East Germany',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 977,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Manfred Deckert',
#   'sport': 'Ski Jumping',
#   'year': 1980},
#  {'age': 20.0,
#   'country': 'Japan',
#   'event': "Men's Normal Hill, Individual",
#   'gender': 'Men',
#   'id': 978,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Hirokazu Yagi',
#   'sport': 'Ski Jumping',
#   'year': 1980},
#  {'age': 25.0,
#   'country': 'Finland',
#   'event': "Men's Large Hill, Individual",
#   'gender': 'Men',
#   'id': 979,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Jouko TÃ¶rmÃ¤nen',
#   'sport': 'Ski Jumping',
#   'year': 1980},
#  {'age': 19.0,
#   'country': 'Austria',
#   'event': "Men's Large Hill, Individual",
#   'gender': 'Men',
#   'id': 980,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Hubert Neuper',
#   'sport': 'Ski Jumping',
#   'year': 1980},
#  {'age': 20.0,
#   'country': 'Finland',
#   'event': "Men's Large Hill, Individual",
#   'gender': 'Men',
#   'id': 981,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Jari Puikkonen',
#   'sport': 'Ski Jumping',
#   'year': 1980},
#  {'age': 21.0,
#   'country': 'United States',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 982,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Eric Heiden',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 29.0,
#   'country': 'Soviet Union',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 983,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Yevgeny Kulikov',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 28.0,
#   'country': 'Netherlands',
#   'event': "Men's 500 Meters",
#   'gender': 'Men',
#   'id': 984,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Lieuwe de Boer',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 21.0,
#   'country': 'United States',
#   'event': "Men's 1,000 Meters",
#   'gender': 'Men',
#   'id': 985,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Eric Heiden',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 21.0,
#   'country': 'Canada',
#   'event': "Men's 1,000 Meters",
#   'gender': 'Men',
#   'id': 986,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'GaÃ©tan Boucher',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 26.0,
#   'country': 'Soviet Union',
#   'event': "Men's 1,000 Meters",
#   'gender': 'Men',
#   'id': 987,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Vladimir Lobanov',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 20.0,
#   'country': 'Norway',
#   'event': "Men's 1,000 Meters",
#   'gender': 'Men',
#   'id': 988,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Frode RÃ¸nning',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 21.0,
#   'country': 'United States',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 989,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Eric Heiden',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 26.0,
#   'country': 'Norway',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 990,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Kay Arne Stenshjemmet',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 27.0,
#   'country': 'Norway',
#   'event': "Men's 1,500 Meters",
#   'gender': 'Men',
#   'id': 991,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Terje Andersen',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 21.0,
#   'country': 'United States',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 992,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Eric Heiden',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 26.0,
#   'country': 'Norway',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 993,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Kay Arne Stenshjemmet',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 20.0,
#   'country': 'Norway',
#   'event': "Men's 5,000 Meters",
#   'gender': 'Men',
#   'id': 994,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Tom Erik Oxholm',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 21.0,
#   'country': 'United States',
#   'event': "Men's 10,000 Meters",
#   'gender': 'Men',
#   'id': 995,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Eric Heiden',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 28.0,
#   'country': 'Netherlands',
#   'event': "Men's 10,000 Meters",
#   'gender': 'Men',
#   'id': 996,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Piet Kleine',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 20.0,
#   'country': 'Norway',
#   'event': "Men's 10,000 Meters",
#   'gender': 'Men',
#   'id': 997,
#   'medal': 'bronze',
#   'medal_rank': 3,
#   'name': 'Tom Erik Oxholm',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 18.0,
#   'country': 'East Germany',
#   'event': "Women's 500 Meters",
#   'gender': 'Women',
#   'id': 998,
#   'medal': 'gold',
#   'medal_rank': 1,
#   'name': 'Karin Enke-Kania',
#   'sport': 'Speedskating',
#   'year': 1980},
#  {'age': 28.0,
#   'country': 'United States',
#   'event': "Women's 500 Meters",
#   'gender': 'Women',
#   'id': 999,
#   'medal': 'silver',
#   'medal_rank': 2,
#   'name': 'Leah Poulos-Mueller',
#   'sport': 'Speedskating',
#   'year': 1980},
#  ...]

# %%
# Use MetaData from SQLAlchemy to reflect the tables
metadata = MetaData(bind=engine)
metadata.reflect()

# %%
# Save the reference to the `medals` table as a variable called `medals_table`
medals_table = sqlalchemy.Table('medals', metadata, autoload=True)

# %%
#Remove any pre-existing data.
conn.execute(medals_table.delete())

# %%
# Insert the data into the table
conn.execute(medals_table.insert(), medals_data)

# %%
# Test that the insert works by fetching the first 5 rows. 
conn.execute("select * from medals limit 5").fetchall()
# Out:
# [(0, 1924, 'Bobsled', "Men's Four/Five", 'Switzerland', 'Men', 1, 'gold', 'Switzerland-1', 0),
#  (1, 1924, 'Bobsled', "Men's Four/Five", 'Britain', 'Men', 2, 'silver', 'Britain-1', 0),
#  (2, 1924, 'Bobsled', "Men's Four/Five", 'Belgium', 'Men', 3, 'bronze', 'Belgium-1', 0),
#  (3, 1924, 'Cross-Country Skiing', "Men's 18 Kilometers", 'Norway', 'Men', 1, 'gold', 'Thorleif Haug', 29),
#  (4, 1924, 'Cross-Country Skiing', "Men's 18 Kilometers", 'Norway', 'Men', 2, 'silver', 'Johan GrÃ¸ttumsbraaten', 24)]
